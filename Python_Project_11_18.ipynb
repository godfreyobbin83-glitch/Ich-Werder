# %% [markdown]
# <a href="https://colab.research.google.com/github/godfreyobbin83-glitch/Ich-Werder/blob/main/Python_Project_11_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Install Libraries

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine, text
from getpass import getpass

# %% [markdown]
# Load Libraries

# %%
df = pd.read_csv('/content/students.csv')

# %%
print ('students', df.shape)
# Out:
# students (100, 4)

# %%
df.head(10)
# Out:
#   first_name last_name date_of_birth        program_of_study
# 0     Thomas   Nkrumah    02/02/2008                 Finance
# 1      Nancy     Jones    06/03/2001                     Law
# 2     George  Frimpong    20/05/2000           Public Health
# 3       Paul      Kumi    27/06/2007  Electrical Engineering
# 4       John     Perez    15/09/2008            Data Science
# 5    Richard     Smith    16/02/2001        Computer Science
# 6       Efua    Miller    17/07/2000  Information Technology
# 7       Mary     Lewis    21/11/1999        Computer Science
# 8    Deborah   Ramirez    18/02/1998                 Finance
# 9    Kwabena   Johnson    15/03/2008       Civil Engineering

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   first_name        100 non-null    object
#  1   last_name         100 non-null    object
#  2   date_of_birth     100 non-null    object
#  3   program_of_study  100 non-null    object
# dtypes: object(4)
# memory usage: 3.3+ KB

# %%
before={
    'rows': len(df),
    'columns': len(df.columns),
    'missing_values': df.isnull().sum().sum(),
    'duplicates': df.duplicated().sum()
}
before
# Out:
# {'rows': 100,
#  'columns': 4,
#  'missing_values': np.int64(0),
#  'duplicates': np.int64(0)}

# %%
df["program_of_study"].value_counts()
# Out:
# program_of_study
# Data Science               9
# Computer Science           8
# Nursing                    8
# Finance                    7
# Cybersecurity              7
# Economics                  6
# Law                        6
# Public Health              6
# Mechanical Engineering     6
# Psychology                 6
# Information Technology     6
# Software Engineering       4
# Architecture               4
# Electrical Engineering     3
# Civil Engineering          3
# Business Administration    3
# Marketing                  3
# Data Analytics             2
# Data Engineering           2
# Accounting                 1
# Name: count, dtype: int64

# %%
df["program_of_study"].nunique()
# Out:
# 20

# %%
df[df["program_of_study"]== "Data Science"]
# Out:
#    first_name last_name date_of_birth program_of_study
# 4        John     Perez    15/09/2008     Data Science
# 24      Newel       Lee    16/09/2006     Data Science
# 26    Kwabena       Lee    19/06/2008     Data Science
# 58    Timothy     Adjei    04/08/2004     Data Science
# 59      Karen   Ramirez    20/10/1999     Data Science
# 70  Elizabeth     Adjei    27/12/2003     Data Science
# 78       Nana     Amoah    19/02/2005     Data Science
# 87     Robert    Asante    14/06/2008     Data Science
# 88     Joshua     Lopez    14/06/2006     Data Science

# %%
df["date_of_birth"] = pd.to_datetime(
    df["date_of_birth"],
    errors="coerce"
    )

# %%
import matplotlib.pyplot as plt

df["program_of_study"].value_counts().plot(
    kind="bar"
)

plt.title("Number of Students per Program")
plt.xlabel("Program of Study")
plt.ylabel("Number of Students")
plt.xticks(rotation=45)
plt.tight_layout() # Adjust layout to prevent labels from overlapping
plt.show()

# %%
import matplotlib.pyplot as plt

df["program_of_study"].value_counts().plot(
    kind="pie"
)

plt.title("Number of Students per Program")
plt.xlabel("Program of Study")
plt.ylabel("Number of Students")
plt.xticks(rotation=45)
plt.show()
